# %%
import os
import time
import pandas as pd
import numpy as np
import networkx as nx
import collections
from scipy import sparse as sp
from scipy.stats import rankdata

import itertools
from itertools import combinations, combinations_with_replacement, cycle
from functools import reduce

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from util import *

import colorcet as cc

# %%
hemibrain_version = "v1.2.1"
log_msg("Hemibrain data set being used:", hemibrain_version)

preproc_dir = "oviIN/preprocessed-" + hemibrain_version
preproc_nodes = "preprocessed_nodes.csv"
preproc_centroids = "x"
preproc_edges = "preprocessed_undirected_edges.csv"

hemibrain_dir = "oviIN/clustering_" + hemibrain_version
hemibrain_nodes = "inputsoutputs_key.txt"
hemibrain_edges = "inputsoutputs.txt"

reneel_params = list(sorted(['0.05','0.1','0.5','0.75'], key=float))
type_params = ['celltype','instance']
list_of_params = reneel_params + type_params

log_msg("Set up directory info and useful lists")

HB_node_df_full = pd.read_csv(os.path.join(preproc_dir, preproc_nodes), index_col=0)
HB_node_df_full["type_group"] = HB_node_df_full["celltype"].apply(simplify_type)
# Out:
# 2023 07 07 15:44:07  Hemibrain data set being used: v1.2.1
# 2023 07 07 15:44:07  Set up directory info and useful lists

# %%
preproc_dir = "oviIN/preprocessed_inputs-" + hemibrain_version
preproc_nodes = "preprocessed_nodes.csv"
preproc_centroids = "x"
preproc_edges = "preprocessed_undirected_edges.csv"

hemibrain_dir = "oviIN/clustering_inputs_" + hemibrain_version
hemibrain_nodes = "only_inputs_key.txt"
hemibrain_edges = "only_inputs.txt"

log_msg("Set up directory info and useful lists")

HB_node_df_in = pd.read_csv(os.path.join(preproc_dir, preproc_nodes), index_col=0)
HB_node_df_in["type_group"] = HB_node_df_in["celltype"].apply(simplify_type)
# Out:
# 2023 07 07 15:44:08  Set up directory info and useful lists

# %%
preproc_dir = "oviIN/preprocessed_outputs-" + hemibrain_version
preproc_nodes = "preprocessed_nodes.csv"
preproc_centroids = "x"
preproc_edges = "preprocessed_undirected_edges.csv"

hemibrain_dir = "oviIN/clustering_outputs_" + hemibrain_version
hemibrain_nodes = "only_outputs_key.txt"
hemibrain_edges = "only_outputs.txt"

log_msg("Set up directory info and useful lists")

HB_node_df_out = pd.read_csv(os.path.join(preproc_dir, preproc_nodes), index_col=0)
HB_node_df_out["type_group"] = HB_node_df_out["celltype"].apply(simplify_type)
# Out:
# 2023 07 07 15:44:10  Set up directory info and useful lists

# %%
HB_node_df_full
# Out:
#              key  0.0  0.05  0.1   0.5  0.75   1.0 instance celltype  pre  \
# id
# 1003215282     1    1     1    1     1     1     1  CL229_R    CL229  100
# 1005952640     2    1     1    2     2     2     2  IB058_R    IB058  664
# 1006928515     3    1     1    1     3     3     3  CL300_R    CL300   86
# 1007260806     4    1     2    1     4     4     4  CL301_R    CL301  119
# 1007402796     5    1     1    2     5     5     5  PS119_R    PS119  245
# ...          ...  ...   ...  ...   ...   ...   ...      ...      ...  ...
# 988269593   4545    3     5    5    95    13  1785   FB4E_L     FB4E  168
# 988291460   4546    4     4  263  1059  1501  1786     None     None    2
# 988567837   4547    5     8    7    13    13    13   FB4G_R     FB4G  785
# 988909130   4548    5     8    7    27    56   436   FB5V_R     FB5V  269
# 989228019   4549    5     8    7    27    56   241   FB5V_R     FB5V  322
#
#             ...  cropped     statusLabel  cellBodyFiber  somaRadius  \
# id          ...
# 1003215282  ...    False  Roughly traced          PDM19       301.0
# 1005952640  ...    False  Roughly traced          PVL20         NaN
# 1006928515  ...    False  Roughly traced          PVL13       236.0
# 1007260806  ...    False  Roughly traced          PVL13       236.0
# 1007402796  ...    False  Roughly traced          PDM16       301.0
# ...         ...      ...             ...            ...         ...
# 988269593   ...    False  Roughly traced          AVM08         NaN
# 988291460   ...      NaN       0.5assign            NaN         NaN
# 988567837   ...    False  Roughly traced          AVM08         NaN
# 988909130   ...    False  Roughly traced          AVM10       296.5
# 989228019   ...    False  Roughly traced          AVM10       296.5
#
#                      somaLocation  \
# id
# 1003215282  [23044, 14981, 11600]
# 1005952640                    NaN
# 1006928515  [12083, 10523, 16816]
# 1007260806  [13524, 10108, 16480]
# 1007402796  [25364, 12010, 12544]
# ...                           ...
# 988269593                     NaN
# 988291460                     NaN
# 988567837                     NaN
# 988909130   [13226, 32024, 18600]
# 989228019   [12516, 33587, 18648]
#
#                                                       roiInfo        notes  \
# id
# 1003215282  {'INP': {'pre': 87, 'post': 351, 'downstream':...          NaN
# 1005952640  {'INP': {'pre': 464, 'post': 1327, 'downstream...          NaN
# 1006928515  {'INP': {'pre': 79, 'post': 126, 'downstream':...          NaN
# 1007260806  {'INP': {'pre': 40, 'post': 128, 'downstream':...          NaN
# 1007402796  {'SNP(R)': {'pre': 100, 'post': 50, 'downstrea...          NaN
# ...                                                       ...          ...
# 988269593   {'SNP(L)': {'post': 25, 'upstream': 25, 'mito'...  CRELALFB4_1
# 988291460   {'SNP(L)': {'pre': 2, 'post': 1, 'downstream':...          NaN
# 988567837   {'SNP(R)': {'pre': 6, 'post': 73, 'downstream'...  CRELALFB4_3
# 988909130   {'SNP(R)': {'pre': 1, 'post': 28, 'downstream'...    CRELALFB5
# 989228019   {'SNP(R)': {'pre': 1, 'post': 45, 'downstream'...    CRELALFB5
#
#                                                     inputRois  \
# id
# 1003215282  ['EPA(R)', 'GOR(R)', 'IB', 'ICL(R)', 'INP', 'S...
# 1005952640  ['ATL(R)', 'IB', 'ICL(R)', 'INP', 'PLP(R)', 'S...
# 1006928515  ['ATL(R)', 'IB', 'ICL(R)', 'INP', 'SCL(R)', 'S...
# 1007260806  ['GOR(R)', 'IB', 'ICL(R)', 'INP', 'PLP(R)', 'S...
# 1007402796  ['CAN(R)', 'GOR(R)', 'IB', 'ICL(L)', 'ICL(R)',...
# ...                                                       ...
# 988269593   ['CRE(-RUB)(L)', 'CRE(L)', 'CX', 'FB', 'FB-col...
# 988291460                                ['SMP(L)', 'SNP(L)']
# 988567837   ['CRE(-ROB,-RUB)(R)', 'CRE(R)', 'CX', 'FB', 'F...
# 988909130   ['AB(R)', 'CRE(-ROB,-RUB)(R)', 'CRE(R)', 'CX',...
# 989228019   ['CRE(-ROB,-RUB)(R)', 'CRE(R)', 'CX', 'FB', 'F...
#
#                                                    outputRois  type_group
# id
# 1003215282  ['GOR(R)', 'IB', 'ICL(R)', 'INP', 'SCL(R)', 'S...          CL
# 1005952640  ['ATL(R)', 'IB', 'ICL(R)', 'INP', 'PLP(R)', 'S...          IB
# 1006928515  ['ATL(R)', 'IB', 'ICL(R)', 'INP', 'SCL(R)', 'S...          CL
# 1007260806  ['IB', 'ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'S...          CL
# 1007402796  ['AVLP(R)', 'CAN(R)', 'IB', 'ICL(L)', 'INP', '...          PS
# ...                                                       ...         ...
# 988269593   ['CRE(-RUB)(L)', 'CRE(L)', 'CX', 'FB', 'FB-col...          FB
# 988291460                                ['SMP(L)', 'SNP(L)']        None
# 988567837   ['CRE(-ROB,-RUB)(R)', 'CRE(R)', 'CX', 'FB', 'F...          FB
# 988909130   ['CRE(-ROB,-RUB)(R)', 'CRE(R)', 'CX', 'FB', 'F...          FB
# 989228019   ['CRE(-ROB,-RUB)(R)', 'CRE(R)', 'CX', 'FB', 'F...          FB
#
# [4549 rows x 26 columns]

# %%
f = HB_node_df_full[HB_node_df_full['0.5']==403]
f[f['0.0']==1]
# Out:
#              key  0.0  0.05  0.1  0.5  0.75   1.0         instance  celltype  \
# id
# 299290105    963    1     1    2  403   522   617         SMP291_R    SMP291
# 358639742   1074    1     1    2  403   522   591         SMP512_R    SMP512
# 360677632   1095    1     1    2  403   522   631         SMP251_R    SMP251
# 449288517   1286    1     1    2  403   691   776         SMP533_R    SMP533
# 453130054   1320    1     1    2  403   522   591         SMP516_R    SMP516
# 481406868   1391    1     1    2  403   522   721         SMP404_R    SMP404
# 481747302   1394    1     1    2  403   522   545         SMP516_R    SMP516
# 484355328   1410    1     1    2  403   522   591         SMP043_R    SMP043
# 511353266   1491    1     1    2  403   691   869         SLP412_R    SLP412
# 511772101   1494    1     1    2  403   522   591             None      None
# 512441111   1497    1     1    2  403   522   872         SMP061_R    SMP061
# 513344531   1503    1     1    2  403   762   750         SMP495_R    SMP495
# 515588291   1524    1     1    2  403   769   880  SMP520(PDM22)_L    SMP520
# 516875221   1540    1     1    2  403   522   591         SMP062_R    SMP062
# 542691005   1606    1     1    2  403   691   869         SMP319_R    SMP319
# 543049093   1609    1     1    2  403   522   869         SMP314_R    SMP314
# 574515806   1835    1     1    2  403   691   869         SMP520_R    SMP520
# 574973454   1839    1     1    2  403   691  1013             None      None
# 576082257   1846    1     1    2  403   522   591         SMP314_R    SMP314
# 5812981016  1957    1     1    2  403   909   617         SMP421_R    SMP421
# 5812981228  1959    1     1    2  403   691   869         SMP319_R    SMP319
# 5812981506  1966    1     1    2  403   691  1062         SMP320_R    SMP320
# 5813021564  2153    1     1    2  403   522   776         SMP410_R    SMP410
# 5813056062  2289    1     1    2  403   522   591             None      None
# 5813056071  2290    1     1    2  403   691   776         SMP331_R    SMP331
# 5813057162  2304    1     1    2  403   763   873         SMP081_R    SMP081
# 5813064332  2353    1     1    2  403   769  1176         SMP201_R    SMP201
# 5813075932  2395    1     1    2  403   691   869         SLP402_R    SLP402
# 5813105726  2470    1     1    2  403   691   869         SLP402_R    SLP402
# 5901196628  2549    1     1    2  403   522   591         SMP315_R    SMP315
# 603482385   2586    1     1    2  403   549   823         SMP528_R    SMP528
# 605550395   2601    1     1    2  403  1021   591         SMP321_R    SMP321
# 605554875   2602    1     1    2  403   691   591         SMP495_R    SMP495
# 607273128   2615    1     1    2  403   522   591         SMP315_R    SMP315
# 608602824   2637    1     1    2  403  1044  1244         SMP317_R    SMP317
# 609655670   2657    1     1    2  403   522   591         SMP315_R    SMP315
# 609893831   2663    1     1    2  403   522   591         SMP043_R    SMP043
# 611340150   2701    1     1    2  403   522   591         SMP317_R    SMP317
# 670020922   2998    1     1    2  403   691   776         SMP331_R    SMP331
# 698314499   3204    1     1    2  403   691  1285         SMP331_R    SMP331
# 698979607   3210    1     1    2  403   691  1062         SMP047_R    SMP047
# 698996246   3211    1     1    2  403  1174   750         SMP413_R    SMP413
# 699695617   3219    1     1    2  403   691   559         SMP331_R    SMP331
# 700037217   3222    1     1    2  403  1174   750         SMP413_R    SMP413
# 701742479   3248    1     1    2  403   649   591       SMP316_b_R  SMP316_b
# 730721558   3452    1     1    2  403   691  1287         SMP331_R    SMP331
# 919168397   4306    1     1    2  403   909   617        AVLP428_R   AVLP428
#
#              pre  ...  cropped     statusLabel  cellBodyFiber  somaRadius  \
# id                ...
# 299290105   1061  ...    False  Roughly traced          PDM05       301.0
# 358639742    440  ...    False  Roughly traced          PDM22       301.0
# 360677632    823  ...    False  Roughly traced          PDL18       311.0
# 449288517    202  ...    False  Roughly traced          PDM24       270.0
# 453130054    422  ...    False  Roughly traced          PDM22       301.0
# 481406868    391  ...    False  Roughly traced          PDM09       316.0
# 481747302    409  ...    False  Roughly traced          PDM22       301.0
# 484355328    272  ...    False  Roughly traced          ADL27       292.5
# 511353266    182  ...    False  Roughly traced          PDM18       254.5
# 511772101    511  ...     True          Leaves            NaN         NaN
# 512441111    291  ...    False  Roughly traced          ADM01       307.0
# 513344531    217  ...    False  Roughly traced          PDM18       227.0
# 515588291    336  ...    False  Roughly traced            NaN       291.0
# 516875221    289  ...    False  Roughly traced          ADM01       307.0
# 542691005    260  ...    False  Roughly traced          PDM06       301.0
# 543049093    320  ...    False  Roughly traced          PDM06       301.0
# 574515806    211  ...    False  Roughly traced          PDM22       236.0
# 574973454    795  ...     True          Leaves            NaN         NaN
# 576082257    320  ...    False  Roughly traced          PDM06       301.0
# 5812981016   259  ...    False  Roughly traced          PDM10       265.5
# 5812981228   268  ...    False  Roughly traced          PDM06       301.0
# 5812981506   285  ...    False  Roughly traced          PDM06       301.0
# 5813021564   256  ...    False  Roughly traced          PDM09       236.0
# 5813056062   538  ...     True          Leaves            NaN         NaN
# 5813056071   165  ...    False  Roughly traced          PDM06       301.0
# 5813057162   890  ...    False  Roughly traced          ADM04       357.0
# 5813064332   497  ...    False  Roughly traced          PDL06       360.0
# 5813075932   143  ...    False  Roughly traced          PDM07       266.0
# 5813105726   140  ...    False  Roughly traced          PDM07       238.5
# 5901196628   178  ...    False  Roughly traced          PDM06       301.0
# 603482385    682  ...    False  Roughly traced          PDM24       388.0
# 605550395    143  ...    False  Roughly traced          PDM06       236.0
# 605554875    397  ...    False  Roughly traced          PDM18       243.0
# 607273128    277  ...    False  Roughly traced          PDM06       301.0
# 608602824    126  ...    False  Roughly traced          PDM06       301.0
# 609655670    243  ...    False  Roughly traced          PDM06       301.0
# 609893831    313  ...    False  Roughly traced          ADL27       292.5
# 611340150    190  ...    False  Roughly traced          PDM06       301.0
# 670020922    196  ...    False  Roughly traced          PDM06       301.0
# 698314499    141  ...    False  Roughly traced          PDM06       301.0
# 698979607    277  ...    False  Roughly traced          ADL29       351.5
# 698996246    198  ...    False  Roughly traced          PDM09       236.0
# 699695617    170  ...    False  Roughly traced          PDM06       236.0
# 700037217    229  ...    False  Roughly traced          PDM09       351.0
# 701742479    263  ...    False  Roughly traced          PDM06       301.0
# 730721558    132  ...    False  Roughly traced          PDM06       236.0
# 919168397    765  ...    False  Roughly traced          AVL23       406.5
#
#                      somaLocation  \
# id
# 299290105   [23184, 12006, 13840]
# 358639742   [20686, 12671, 10864]
# 360677632    [5629, 13062, 14416]
# 449288517    [14961, 19917, 4376]
# 453130054   [20878, 11691, 12736]
# 481406868   [21061, 10439, 16344]
# 481747302    [20594, 14085, 9984]
# 484355328   [12026, 32944, 13232]
# 511353266    [17409, 23962, 3412]
# 511772101                     NaN
# 512441111    [22985, 30900, 6456]
# 513344531    [17855, 25920, 3660]
# 515588291   [29503, 12938, 12280]
# 516875221    [20902, 30646, 6528]
# 542691005    [21281, 14673, 8848]
# 543049093   [22156, 13302, 11792]
# 574515806   [20162, 10632, 13448]
# 574973454                     NaN
# 576082257   [22595, 13979, 11504]
# 5812981016   [12503, 18440, 4800]
# 5812981228  [21083, 13133, 10896]
# 5812981506   [21775, 13848, 9936]
# 5813021564  [20929, 10952, 16760]
# 5813056062                    NaN
# 5813056071   [21935, 14016, 9344]
# 5813057162  [23987, 33592, 12152]
# 5813064332    [5850, 16795, 5096]
# 5813075932   [15497, 26195, 4544]
# 5813105726   [13874, 23822, 4104]
# 5901196628  [23135, 12575, 13872]
# 603482385    [13364, 15710, 8104]
# 605550395    [22159, 14387, 9136]
# 605554875    [17875, 21654, 3876]
# 607273128    [21807, 14431, 9712]
# 608602824   [22686, 13544, 10208]
# 609655670   [21928, 13108, 12192]
# 609893831   [11649, 33160, 14176]
# 611340150    [21010, 14554, 9888]
# 670020922   [21695, 13081, 11328]
# 698314499   [22414, 13009, 10688]
# 698979607    [3548, 26175, 20000]
# 698996246   [20793, 10963, 15968]
# 699695617    [21870, 14242, 8912]
# 700037217   [21142, 11831, 17056]
# 701742479   [21821, 14111, 11328]
# 730721558    [22273, 14484, 8464]
# 919168397   [11713, 33421, 22232]
#
#                                                       roiInfo notes  \
# id
# 299290105   {'SNP(R)': {'pre': 1056, 'post': 4001, 'downst...   NaN
# 358639742   {'SNP(R)': {'pre': 263, 'post': 1788, 'downstr...   NaN
# 360677632   {'SNP(R)': {'pre': 440, 'post': 2116, 'downstr...   NaN
# 449288517   {'SNP(R)': {'pre': 202, 'post': 1173, 'downstr...   NaN
# 453130054   {'SNP(R)': {'pre': 249, 'post': 1650, 'downstr...   NaN
# 481406868   {'SNP(R)': {'pre': 391, 'post': 2115, 'downstr...   NaN
# 481747302   {'SNP(R)': {'pre': 234, 'post': 1740, 'downstr...   NaN
# 484355328   {'SNP(R)': {'pre': 270, 'post': 592, 'downstre...   NaN
# 511353266   {'SNP(R)': {'pre': 160, 'post': 505, 'downstre...   NaN
# 511772101   {'SNP(R)': {'pre': 324, 'post': 317, 'downstre...   NaN
# 512441111   {'SNP(R)': {'pre': 247, 'post': 3127, 'downstr...   NaN
# 513344531   {'SNP(R)': {'pre': 217, 'post': 994, 'downstre...   NaN
# 515588291   {'SNP(L)': {'pre': 152, 'post': 614, 'downstre...   NaN
# 516875221   {'SNP(R)': {'pre': 208, 'post': 2513, 'downstr...   NaN
# 542691005   {'SNP(R)': {'pre': 247, 'post': 587, 'downstre...   NaN
# 543049093   {'SNP(R)': {'pre': 314, 'post': 939, 'downstre...   NaN
# 574515806   {'SNP(R)': {'pre': 118, 'post': 513, 'downstre...   NaN
# 574973454   {'SNP(L)': {'pre': 181, 'post': 596, 'downstre...   NaN
# 576082257   {'SNP(R)': {'pre': 313, 'post': 1147, 'downstr...   NaN
# 5812981016  {'SNP(R)': {'pre': 248, 'post': 414, 'downstre...   NaN
# 5812981228  {'SNP(R)': {'pre': 264, 'post': 557, 'downstre...   NaN
# 5812981506  {'SNP(R)': {'pre': 255, 'post': 571, 'downstre...   NaN
# 5813021564  {'SNP(R)': {'pre': 243, 'post': 799, 'downstre...   NaN
# 5813056062  {'SNP(R)': {'pre': 345, 'post': 308, 'downstre...   NaN
# 5813056071  {'SNP(R)': {'pre': 148, 'post': 391, 'downstre...   NaN
# 5813057162  {'SNP(R)': {'pre': 876, 'post': 9447, 'downstr...   NaN
# 5813064332  {'SNP(R)': {'pre': 464, 'post': 1229, 'downstr...   NaN
# 5813075932  {'SNP(R)': {'pre': 132, 'post': 413, 'downstre...   NaN
# 5813105726  {'SNP(R)': {'pre': 138, 'post': 415, 'downstre...   NaN
# 5901196628  {'SNP(R)': {'pre': 175, 'post': 715, 'downstre...   NaN
# 603482385   {'SNP(R)': {'pre': 667, 'post': 2016, 'downstr...   NaN
# 605550395   {'SNP(R)': {'pre': 140, 'post': 511, 'downstre...   NaN
# 605554875   {'SNP(R)': {'pre': 347, 'post': 1748, 'downstr...   NaN
# 607273128   {'SNP(R)': {'pre': 266, 'post': 1121, 'downstr...   NaN
# 608602824   {'SNP(R)': {'pre': 125, 'post': 460, 'downstre...   NaN
# 609655670   {'SNP(R)': {'pre': 240, 'post': 984, 'downstre...   NaN
# 609893831   {'SNP(R)': {'pre': 303, 'post': 590, 'downstre...   NaN
# 611340150   {'SNP(R)': {'pre': 187, 'post': 622, 'downstre...   NaN
# 670020922   {'SNP(R)': {'pre': 172, 'post': 408, 'downstre...   NaN
# 698314499   {'SNP(R)': {'pre': 124, 'post': 357, 'downstre...   NaN
# 698979607   {'SNP(R)': {'pre': 273, 'post': 486, 'downstre...   NaN
# 698996246   {'SNP(R)': {'pre': 152, 'post': 382, 'downstre...   NaN
# 699695617   {'SNP(R)': {'pre': 151, 'post': 430, 'downstre...   NaN
# 700037217   {'SNP(R)': {'pre': 170, 'post': 463, 'downstre...   NaN
# 701742479   {'SNP(R)': {'pre': 261, 'post': 725, 'downstre...   NaN
# 730721558   {'SNP(R)': {'pre': 119, 'post': 468, 'downstre...   NaN
# 919168397   {'SNP(R)': {'pre': 392, 'post': 889, 'downstre...   NaN
#
#                                                     inputRois  \
# id
# 299290105   ['ATL(R)', 'INP', 'SCL(R)', 'SIP(R)', 'SMP(R)'...
# 358639742   ['INP', 'SCL(R)', 'SMP(L)', 'SMP(R)', 'SNP(L)'...
# 360677632   ['ATL(R)', 'INP', 'SCL(R)', 'SIP(R)', 'SMP(L)'...
# 449288517   ['INP', 'MB(+ACA)(R)', 'SCL(R)', 'SLP(R)', 'SM...
# 453130054   ['INP', 'SCL(R)', 'SLP(R)', 'SMP(L)', 'SMP(R)'...
# 481406868     ['ATL(R)', 'INP', 'SIP(R)', 'SMP(R)', 'SNP(R)']
# 481747302   ['INP', 'SCL(R)', 'SLP(R)', 'SMP(L)', 'SMP(R)'...
# 484355328   ['AVLP(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SLP(R)...
# 511353266   ['INP', 'MB(+ACA)(R)', 'PLP(R)', 'SCL(R)', 'SL...
# 511772101            ['SMP(L)', 'SMP(R)', 'SNP(L)', 'SNP(R)']
# 512441111            ['SMP(L)', 'SMP(R)', 'SNP(L)', 'SNP(R)']
# 513344531   ['INP', 'MB(+ACA)(R)', 'SCL(R)', 'SLP(R)', 'SM...
# 515588291   ['INP', 'SCL(L)', 'SMP(L)', 'SMP(R)', 'SNP(L)'...
# 516875221            ['SMP(L)', 'SMP(R)', 'SNP(L)', 'SNP(R)']
# 542691005   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 543049093   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 574515806   ['INP', 'SCL(R)', 'SMP(L)', 'SMP(R)', 'SNP(L)'...
# 574973454   ['ATL(L)', 'ATL(R)', 'IB', 'ICL(L)', 'INP', 'S...
# 576082257   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 5812981016  ['INP', 'LH(R)', 'MB(+ACA)(R)', 'PLP(R)', 'SCL...
# 5812981228  ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 5812981506  ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'SCL(R)', 'SL...
# 5813021564  ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 5813056062  ['SLP(R)', 'SMP(L)', 'SMP(R)', 'SNP(L)', 'SNP(...
# 5813056071  ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 5813057162  ['ATL(R)', 'CRE(-ROB,-RUB)(R)', 'CRE(R)', 'IB'...
# 5813064332  ['CA(R)', 'ICL(R)', 'INP', 'MB(+ACA)(R)', 'MB(...
# 5813075932  ['INP', 'MB(+ACA)(R)', 'PLP(R)', 'SCL(R)', 'SL...
# 5813105726  ['INP', 'MB(+ACA)(R)', 'SCL(R)', 'SLP(R)', 'SM...
# 5901196628  ['AVLP(R)', 'IB', 'ICL(R)', 'INP', 'PLP(R)', '...
# 603482385   ['ICL(R)', 'INP', 'LH(R)', 'LO(R)', 'MB(+ACA)(...
# 605550395   ['GOR(R)', 'IB', 'ICL(R)', 'INP', 'PLP(R)', 'S...
# 605554875   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 607273128   ['AVLP(R)', 'ICL(R)', 'INP', 'PLP(R)', 'SCL(R)...
# 608602824   ['ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SLP(R)'...
# 609655670   ['AVLP(R)', 'ICL(R)', 'INP', 'PLP(R)', 'SCL(R)...
# 609893831   ['AVLP(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SLP(R)...
# 611340150   ['ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SLP(R)'...
# 670020922   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 698314499   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 698979607   ['AOTU(R)', 'INP', 'MB(+ACA)(R)', 'SCL(R)', 'S...
# 698996246   ['ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SLP(R)'...
# 699695617   ['ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SLP(R)'...
# 700037217   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 701742479   ['ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SLP(R)'...
# 730721558   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...
# 919168397   ['AVLP(R)', 'CRE(-ROB,-RUB)(R)', 'CRE(R)', 'IC...
#
#                                                    outputRois  type_group
# id
# 299290105     ['INP', 'SCL(R)', 'SIP(R)', 'SMP(R)', 'SNP(R)']         SMP
# 358639742   ['INP', 'SCL(R)', 'SMP(L)', 'SMP(R)', 'SNP(L)'...         SMP
# 360677632   ['INP', 'SCL(R)', 'SIP(R)', 'SMP(L)', 'SMP(R)'...         SMP
# 449288517                      ['SLP(R)', 'SMP(R)', 'SNP(R)']         SMP
# 453130054   ['INP', 'SCL(R)', 'SMP(L)', 'SMP(R)', 'SNP(L)'...         SMP
# 481406868                      ['SIP(R)', 'SMP(R)', 'SNP(R)']         SMP
# 481747302   ['INP', 'SCL(R)', 'SLP(R)', 'SMP(L)', 'SMP(R)'...         SMP
# 484355328   ['AVLP(R)', 'INP', 'SCL(R)', 'SLP(R)', 'SMP(R)...         SMP
# 511353266   ['INP', 'LH(R)', 'MB(+ACA)(R)', 'PLP(R)', 'SCL...         SLP
# 511772101            ['SMP(L)', 'SMP(R)', 'SNP(L)', 'SNP(R)']        None
# 512441111            ['SMP(L)', 'SMP(R)', 'SNP(L)', 'SNP(R)']         SMP
# 513344531                      ['SLP(R)', 'SMP(R)', 'SNP(R)']         SMP
# 515588291   ['INP', 'SCL(L)', 'SMP(L)', 'SMP(R)', 'SNP(L)'...         SMP
# 516875221            ['SMP(L)', 'SMP(R)', 'SNP(L)', 'SNP(R)']         SMP
# 542691005   ['INP', 'MB(+ACA)(R)', 'SCL(R)', 'SLP(R)', 'SM...         SMP
# 543049093   ['ICL(R)', 'INP', 'SCL(R)', 'SLP(R)', 'SMP(R)'...         SMP
# 574515806   ['INP', 'SCL(R)', 'SMP(L)', 'SMP(R)', 'SNP(L)'...         SMP
# 574973454   ['ATL(L)', 'ATL(R)', 'IB', 'INP', 'SCL(R)', 'S...        None
# 576082257   ['ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SIP(R)'...         SMP
# 5812981016  ['INP', 'MB(+ACA)(R)', 'PLP(R)', 'SCL(R)', 'SL...         SMP
# 5812981228  ['INP', 'MB(+ACA)(R)', 'SCL(R)', 'SLP(R)', 'SM...         SMP
# 5812981506  ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'SCL(R)', 'SL...         SMP
# 5813021564  ['INP', 'MB(+ACA)(R)', 'SCL(R)', 'SLP(R)', 'SM...         SMP
# 5813056062  ['SLP(R)', 'SMP(L)', 'SMP(R)', 'SNP(L)', 'SNP(...        None
# 5813056071  ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...         SMP
# 5813057162  ['ATL(R)', 'CRE(-ROB,-RUB)(R)', 'CRE(R)', 'INP...         SMP
# 5813064332  ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...         SMP
# 5813075932  ['INP', 'MB(+ACA)(R)', 'SCL(R)', 'SLP(R)', 'SM...         SLP
# 5813105726  ['INP', 'MB(+ACA)(R)', 'SCL(R)', 'SLP(R)', 'SM...         SLP
# 5901196628  ['INP', 'SCL(R)', 'SIP(R)', 'SMP(R)', 'SNP(R)'...         SMP
# 603482385   ['INP', 'LH(R)', 'MB(+ACA)(R)', 'PLP(R)', 'SCL...         SMP
# 605550395   ['ICL(R)', 'INP', 'SCL(R)', 'SLP(R)', 'SMP(R)'...         SMP
# 605554875   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...         SMP
# 607273128   ['ICL(R)', 'INP', 'SCL(R)', 'SIP(R)', 'SLP(R)'...         SMP
# 608602824               ['INP', 'SCL(R)', 'SMP(R)', 'SNP(R)']         SMP
# 609655670   ['INP', 'PLP(R)', 'SCL(R)', 'SIP(R)', 'SLP(R)'...         SMP
# 609893831   ['AVLP(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SIP(R)...         SMP
# 611340150     ['ICL(R)', 'INP', 'SCL(R)', 'SMP(R)', 'SNP(R)']         SMP
# 670020922   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...         SMP
# 698314499   ['ICL(R)', 'INP', 'MB(+ACA)(R)', 'PLP(R)', 'SC...         SMP
# 698979607   ['INP', 'SCL(R)', 'SIP(R)', 'SLP(R)', 'SMP(R)'...         SMP
# 698996246   ['ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SLP(R)'...         SMP
# 699695617   ['ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SLP(R)'...         SMP
# 700037217   ['ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SLP(R)'...         SMP
# 701742479   ['ICL(R)', 'INP', 'SCL(R)', 'SLP(R)', 'SMP(R)'...         SMP
# 730721558   ['ICL(R)', 'INP', 'PLP(R)', 'SCL(R)', 'SMP(R)'...         SMP
# 919168397   ['AVLP(R)', 'CRE(-ROB,-RUB)(R)', 'CRE(R)', 'IC...        AVLP
#
# [47 rows x 26 columns]
